# %% [markdown]
# ![CapaForum4.png](attachment:CapaForum4.png)

# %% [markdown]
# Na videoaula de hoje, discutimos questões éticas e sociais envolvendo a Inteligência Artificial (IA), abordando temas como preconceito, discriminação e responsabilidade. Vimos como a IA impacta diversas áreas da vida, trazendo benefícios, mas também desafios. Agora, queremos ouvir suas reflexões!

# %% [markdown]
# Perguntas para reflexão e discussão:

# %% [markdown]
# # Questão 1:
#
# A IA está presente em muitos aspectos de nossa vida, como redes sociais, saúde e transporte. Na sua opinião, quais cuidados devemos tomar para garantir que essa tecnologia beneficie a todos de forma justa?

# %% [markdown]
# # Resposta:

# %% [markdown]
# # Questão 2:
#
# Vimos que modelos de IA podem reproduzir preconceitos presentes nos dados com os quais são treinados. Como você acha que isso pode impactar a sociedade e o que pode ser feito para evitar esses problemas?

# %% [markdown]
# # Resposta:

# %% [markdown]
# # Questão 3:
#
# Enquanto a IA transforma setores como saúde e educação, também pode gerar desigualdade social, como a substituição de empregos. Quais medidas você acredita que podem ser tomadas para equilibrar os avanços tecnológicos com o bem-estar social?

# %% [markdown]
# # Resposta:

# %% [markdown]
# Vamos lá, estudante! Compartilhe suas ideias com base nos conceitos apresentados e reflitam sobre como podemos construir um futuro mais ético e justo com o uso da IA. Vamos promover um debate enriquecedor para todos!
